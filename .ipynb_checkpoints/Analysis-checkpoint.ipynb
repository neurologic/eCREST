# %% [markdown]
# # Analysis

# %% [markdown]
# ## Setup

# %%
############################################################################################################################ 
# Get the latest CREST files for each ID within the target folder (dirname)

from pathlib import Path
import json
from sqlite3 import connect as sqlite3_connect
from sqlite3 import DatabaseError
from igraph import Graph as ig_Graph
from igraph import plot as ig_plot
from scipy.spatial.distance import cdist
from random import choice as random_choice
from itertools import combinations
from numpy import array, unravel_index, argmin, mean
import numpy as np
from copy import deepcopy
import itertools
from datetime import datetime
from time import time
import neuroglancer
from webbrowser import open as wb_open
from webbrowser import open_new as wb_open_new
import pandas as pd

from eCREST_cli import ecrest, import_settings

# %% [markdown]
# The 'ecrest' class has been imported from eCREST_cli.py
#
# An instance of this object will be able to:
# - open an neuroglancer viewer for proofrieading (see "Proofread using CREST")
#     - add-remove segments (using graph feature for efficiency)
#     - format itself and save itself as a CREST-style .json
# - convert from neuroglancer json (see "Convert From Neuroglancer to eCREST")
#     - format itself and save itself as a CREST-style .json

# %% [markdown]
# ### Import settings
#
# If you save a copy of settings_dict.json (found in the "under construction" directory of eCREST repo) locally somewhere outside the repo (like in your save_dir), then you can use the following code cell to import. This avoids needing to re-type the save_dir and db_path each time you "git pull" updates from the repo to this notebook.

# %%
path_to_settings_json = '/Users/kperks/Documents/ell-connectome/eCREST-local-files/settings_dict.json'
settings_dict = import_settings(path_to_settings_json)

# %% [markdown]
# ## Build connectivity graph

# %%
dirpath = Path(settings_dict['save_dir'])
# dirpath = "/Users/kperks/Documents/gdrive/.shortcut-targets-by-id/16q1BuOMfD2ta0Cwq8CjMlRe4rDvbuWC5/ELL_connectome/CREST_reconstructions/mg-network"

# %%
nodes = [child.name.split('_')[2] for child in sorted(dirpath.iterdir()) 
         if (child.name[0]!='.') & (child.is_file())] # ignore hidden files]

nodefiles = dict()
for child in sorted(dirpath.iterdir()):
    if (child.name[0]!='.') & (child.is_file()):
        nodefiles[child.name.split('_')[2]] = child
                    
for x in nodes:
    cell = ecrest(settings_dict,filepath = nodefiles[x],launch_viewer=False)
    cell_type = cell.get_ctype('manual') 
    if (cell.get_ctype('manual') == []) | (cell.get_ctype('manual') == ''):
        print(f'cell {x} is not cell-typed in json')

# %%
# # IF NEED TO CELL TYPE....


# json_path = Path(settings_dict['save_dir'])
# filename = 'cell_graph_43884064__2023-04-13 10.31.05.json'

# crest = ecrest(settings_dict,filepath= json_path / filename, launch_viewer=False)


# # Assign the cell type and which method you are using (manual or auto)
# cell_type = 'mg1'
# method = 'manual'

# ## Do not edit
# crest.define_ctype(cell_type,method)

# filepath = json_path / filename
# crest.save_cell_graph(directory_path = filepath.parent, file_name=filepath.name, save_to_cloud=False);
# Out:
# Saved cell 43884064 reconstruction locally at 2023-04-13 15.59.05

# %%
# Create a base_segments dictionary of all cells

base_segments = {}
for x in nodes:
    cell = ecrest(settings_dict,filepath = nodefiles[x],launch_viewer=False)
    base_segments[cell.cell_data['metadata']['main_seg']['base']] = cell.cell_data['base_segments']

# %%
ell = ig_Graph(directed = True) 
ell.add_vertices(nodes)

# assign cell types to each node
for x in ell.vs:
    cell = ecrest(settings_dict,filepath = nodefiles[x['name']],launch_viewer=False)
    x['cell_type'] = cell.get_ctype('manual') 
    if (cell.get_ctype('manual') == []) | (cell.get_ctype('manual') == ''):
        print(f'cell {x["name"]} is not typed in json')

# use this code cell to delete some of the vertices (cells)
# if want to focus on a graph among a set of subtypes

'''see if this can be done later (and saved as a diff graph)'''

to_delete_ids = [v.index for v in ell.vs if v['cell_type'] not in ['mg2','lg','mg1','lf']]
ell.delete_vertices(to_delete_ids)

for ctype in ['lf','lg','mg1','mg2','lx','mgx']:
    these_cells = ell.vs.select(lambda v: ctype in v['cell_type'])
    print(f'{len(these_cells)} {ctype} cells.')# {len(ell.vs.select(lambda v: 'lg' in v['cell_type']))} lg cells. {len(e

## find edges and set the cell-structure attribute of the edge based on which part of the cell the edge goes to
edge_list = []
cells_with_synapses = []
cells_without_synapses = []
# for each node,
for x_pre in ell.vs:
# x_pre = ell.vs.find('128473437')

    # if the node has post-synaptic annotations (the current cell is assumed pre-synaptic)
    pre = ecrest(settings_dict,filepath = nodefiles[x_pre['name']],launch_viewer=False)
    if pre.cell_data['end_points']['post-synaptic'] != []:
        
        cells_with_synapses.append([x_pre['name'],x_pre['cell_type'],len(pre.cell_data['end_points']['post-synaptic'])])
        
        # for each synapse
        for syn_ in pre.cell_data['end_points']['post-synaptic']:
            try:
                post_seg = syn_[3]

                # go through each other nodes
                for x_post in ell.vs:
                # x_post = ell.vs.find('387368998')

                    post = base_segments[x_post['name']] #ecrest(settings_dict,filepath = nodefiles[x_post['name']],launch_viewer=False)


                    for k,v in post.items():

                        for v_ in list(v): #find keys (can be multiple on the same cell) for matching segment ids

                            if post_seg == v_: 

                            # add edge to the graph between current node and matching node
                                edge_list.append([x_pre['name'],x_post['name'],k])

                            # what happens if the edge already exists? can you "add another" or does the "strength" attribute increase?

                            # set edge attribute for cell structure of edge

                            # ****HOW MAKE THIS DIRECTED?
            except IndexError as msg:
                cellid = x_pre['name']
                print(msg, f'for cell {cellid} synapse at syn_ has no segment id')

    else:
        cells_without_synapses.append([x_pre['name'],x_pre['cell_type'],len(pre.cell_data['end_points']['post-synaptic'])])
        cellid = x_pre['name']
        # print(f'no synapses for {cellid}')
# Out:
# 25 lf cells.
# 20 lg cells.
# 17 mg1 cells.
# 16 mg2 cells.
# 0 lx cells.
# 0 mgx cells.

# %%
cells_with_synapses

df_allsyn = pd.DataFrame(cells_with_synapses)

print(f'{df_allsyn[df_allsyn[1].str.contains("mg")][2].sum()} total post-synapstic segments labeled in the network')
# Out:
# 1470 total post-synapstic segments labeled in the network

# %%
cells_without_synapses

df_nosyn = pd.DataFrame(cells_without_synapses)

df_nosyn[df_nosyn[1].str.contains("mg")]
# Out:
#             0    1  2
# 1   126635405  mg1  0
# 2   127870654  mg1  0
# 11  215495298  mg1  0
# 13  299249397  mg2  0
# 14  300459385  mg1  0
# 24  388483828  mg2  0
# 33   43884064  mg1  0
# 36  472114046  mg1  0

# %%
edge_scaling = 10

df = pd.DataFrame(edge_list,columns = ['pre','post','structure'])
df_edges = deepcopy(df.value_counts().reset_index(name='weight'))
df_edges['weight_norm'] = (df_edges['weight'] / df_edges['weight'].max()) * edge_scaling

for i,r in df_edges.iterrows():
    ell.add_edge(r['pre'],r['post'],weight = r['weight_norm'],structure = r['structure'])
    
# # if need to delete all edges...
# ell.delete_edges(range(len(ell.es)))

# for each unique edge, get the cell-type pair and structure

for i,r in df_edges.iterrows():
    df_edges.loc[i,'pre_type']=ell.vs.find(r['pre'])['cell_type']
    df_edges.loc[i,'post_type']=ell.vs.find(r['post'])['cell_type']
    # print(ell.vs.find(r['pre'])['cell_type'])
    # print(ell.vs.find(r['post'])['cell_type'])

# %%
# if need to delete all edges...
ell.delete_edges(range(len(ell.es)))

# %%
print(f'{len(df)} synapses with reconstructed partners in current network,')
print(f'{df_edges[df_edges["pre_type"].str.contains("mg")]["weight"].sum()} synapses with reconstructed partners from mg cells pre-synaptically.')

# print(f'comprising {len(df_edges)} unique edges among:')
print(f'{df_edges[["pre_type","post_type","structure"]].value_counts().reset_index(name="counts")["counts"].sum()} unique edges among:')
print(f'{len(df["pre"].unique())} unique pre synaptic cells - to - {len(df["post"].unique())} unique post-synaptic cells (counts different structures on same cell as different)')

print(f'{len(np.unique(df_edges[df_edges["pre_type"]=="mg1"]["pre"]))} mg1 cells with ')
print(f'{df_edges[df_edges["pre_type"]=="mg1"]["weight"].sum()} connected synapses with a reconstructed partner in these mg1')

print(f'{len(np.unique(df_edges[df_edges["pre_type"]=="mg2"]["pre"]))} mg2 cells')
print(f'{df_edges[df_edges["pre_type"]=="mg2"]["weight"].sum()} connected synapses with a reconstructed partner in these mg2')

with pd.option_context('display.max_rows', 4):
    display(df_edges)
# Out:
# 706 synapses with reconstructed partners in current network,
# 706 synapses with reconstructed partners from mg cells pre-synaptically.
# 211 unique edges among:
# 25 unique pre synaptic cells - to - 68 unique post-synaptic cells (counts different structures on same cell as different)
# 11 mg1 cells with
# 308 connected synapses with a reconstructed partner in these mg1
# 14 mg2 cells
# 398 connected synapses with a reconstructed partner in these mg2
#            pre       post       structure  weight  weight_norm pre_type  \
# 0    472175645  393063300         unknown      20         5.00      mg1
# 1    472051969  558020412         unknown      15         3.75      mg2
# ..         ...        ...             ...     ...          ...      ...
# 209  299404889  558020412         unknown       1         0.25      mg2
# 210  302143252  213605530  basal dendrite       1         0.25      mg1
#
#     post_type
# 0          lf
# 1          lg
# ..        ...
# 209        lg
# 210       mg2
#
# [211 rows x 7 columns]

# %%
df_edge_counts = df_edges[['pre_type','post_type','structure']].value_counts().reset_index(name='counts')

mask = df_edge_counts['pre_type'].str.lower().isin(['mg1']) & df_edge_counts['post_type'].str.lower().isin(['lf'])
display(df_edge_counts[mask])

mask = df_edges['pre_type'].str.lower().isin(['mg1']) & df_edges['post_type'].str.lower().isin(['lf'])
display(df_edges[mask].groupby(['pre_type','post_type','structure']).sum(numeric_only=True))

mask = df_edge_counts['pre_type'].str.lower().isin(['mg2']) & df_edge_counts['post_type'].str.lower().isin(['lg'])
display(df_edge_counts[mask])

mask = df_edges['pre_type'].str.lower().isin(['mg2']) & df_edges['post_type'].str.lower().isin(['lg'])
display(df_edges[mask].groupby(['pre_type','post_type','structure']).sum(numeric_only=True))

mask = df_edge_counts['pre_type'].str.lower().isin(['mg1']) & df_edge_counts['post_type'].str.lower().isin(['mg2'])
display(df_edge_counts[mask])

mask = df_edges['pre_type'].str.lower().isin(['mg1']) & df_edges['post_type'].str.lower().isin(['mg2'])
display(df_edges[mask].groupby(['pre_type','post_type','structure']).sum(numeric_only=True))

mask = df_edge_counts['pre_type'].str.lower().isin(['mg2']) & df_edge_counts['post_type'].str.lower().isin(['mg1'])
display(df_edge_counts[mask])

mask = df_edges['pre_type'].str.lower().isin(['mg2']) & df_edges['post_type'].str.lower().isin(['mg1'])
display(df_edges[mask].groupby(['pre_type','post_type','structure']).sum(numeric_only=True))
# Out:
#    pre_type post_type        structure  counts
# 1       mg1        lf          unknown      46
# 7       mg1        lf  apical dendrite       8
# 10      mg1        lf   basal dendrite       6
# 11      mg1        lf         multiple       5
#                                     weight  weight_norm
# pre_type post_type structure
# mg1      lf        apical dendrite      26         6.50
#                    basal dendrite       16         4.00
#                    multiple             12         3.00
#                    unknown             197        49.25
#    pre_type post_type        structure  counts
# 0       mg2        lg          unknown      53
# 5       mg2        lg   basal dendrite      13
# 6       mg2        lg         multiple       9
# 8       mg2        lg  apical dendrite       7
# 12      mg2        lg             axon       2
#                                     weight  weight_norm
# pre_type post_type structure
# mg2      lg        apical dendrite      11         2.75
#                    axon                  2         0.50
#                    basal dendrite       43        10.75
#                    multiple             40        10.00
#                    unknown             235        58.75
#    pre_type post_type        structure  counts
# 2       mg1       mg2   basal dendrite      17
# 9       mg1       mg2          unknown       6
# 13      mg1       mg2         multiple       2
# 14      mg1       mg2             axon       2
# 17      mg1       mg2  apical dendrite       1
#                                     weight  weight_norm
# pre_type post_type structure
# mg1      mg2       apical dendrite       3         0.75
#                    axon                  5         1.25
#                    basal dendrite       30         7.50
#                    multiple              4         1.00
#                    unknown              15         3.75
#    pre_type post_type        structure  counts
# 3       mg2       mg1   basal dendrite      15
# 4       mg2       mg1          unknown      14
# 15      mg2       mg1  apical dendrite       2
# 16      mg2       mg1         multiple       2
# 18      mg2       mg1             axon       1
#                                     weight  weight_norm
# pre_type post_type structure
# mg2      mg1       apical dendrite       4         1.00
#                    axon                  1         0.25
#                    basal dendrite       36         9.00
#                    multiple              3         0.75
#                    unknown              23         5.75

# %%
color_dict = {"mg1": "orange", "lf": "red", "mg2": "purple", "lg": "blue"}

# for cell_type in ell.vs["cell_type"]:

for v in ell.vs:
    try:
        v["color"] = color_dict[v['cell_type']]
    except:
        v["color"] = 'black'
# ell.vs["color"] = [try: color_dict[cell_type] except: 'black' for cell_type in ell.vs["cell_type"]]

# %%
color_dict = {"unknown": "tan", "apical dendrite": "red", "basal dendrite": "orange", "axon": "green", "multiple":"gray"}

# for cell_type in ell.vs["cell_type"]:

for e in ell.es:
    try:
        e["color"] = color_dict[e['structure']]
    except:
        e["color"] = 'black'
        print(e)

# %%
degree_all = ell.degree(mode="out")

# for i,d in enumerate(degree_all):
    # print(ell.vs[i]['cell_type'],d)

# labels = [n['name'] for n in ell.vs]

visual_style = {}
visual_style["layout"] = ell.layout("fr")
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = "white"
visual_style["vertex_label"] = degree_all
# visual_style["arrow_size"]=0.1


ig_plot(ell,edge_width = ell.es['weight'],
        vertex_color=ell.vs['color'],
        edge_color = ell.es['color'], 
        **visual_style)#,vertex_label=labels)

# %%
pruned_vs = ell.vs.select([v for v, b in enumerate(ell.vs) if 'mg' in b['cell_type']])

pruned_graph = ell.subgraph(pruned_vs)

degree_all = pruned_graph.degree(mode="in")

visual_style = {}
# visual_style["layout"] = ell.layout("fr")
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = "white"
visual_style["vertex_label"] = degree_all

ig_plot(pruned_graph,edge_width = pruned_graph.es['weight'],
        vertex_color=pruned_graph.vs['color'],
        edge_color = pruned_graph.es['color'],
        **visual_style)#,vertex_label=labels)

# %%
pruned_vs = ell.vs.select([v for v, b in enumerate(ell.vs) if b['cell_type'] in ['mg2','lg']])

pruned_graph = ell.subgraph(pruned_vs)

degree_all = pruned_graph.degree(mode="in")

visual_style = {}
# visual_style["layout"] = ell.layout("fr")
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = "white"
visual_style["vertex_label"] = degree_all

ig_plot(pruned_graph,edge_width = pruned_graph.es['weight'],
        vertex_color=pruned_graph.vs['color'],
        edge_color = pruned_graph.es['color'], 
        **visual_style)#,vertex_label=labels)

# %%
pruned_vs = ell.vs.select([v for v, b in enumerate(ell.vs) if b['cell_type'] in ['mg2','lf']])

pruned_graph = ell.subgraph(pruned_vs)

degree_all = pruned_graph.degree(mode="in")

visual_style = {}
# visual_style["layout"] = ell.layout("fr")
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = "white"
visual_style["vertex_label"] = degree_all

ig_plot(pruned_graph,edge_width = pruned_graph.es['weight'],
        vertex_color=pruned_graph.vs['color'],
        edge_color = pruned_graph.es['color'], 
        **visual_style)#,vertex_label=labels)

# %%
pruned_vs = ell.vs.select([v for v, b in enumerate(ell.vs) if b['cell_type'] in ['mg1','lf']])

pruned_graph = ell.subgraph(pruned_vs)

degree_all = pruned_graph.degree(mode="in")

visual_style = {}
# visual_style["layout"] = ell.layout("fr")
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = "white"
visual_style["vertex_label"] = degree_all

ig_plot(pruned_graph,edge_width = pruned_graph.es['weight'],
        vertex_color=pruned_graph.vs['color'],
        edge_color = pruned_graph.es['color'], 
        **visual_style)#,vertex_label=labels)

# %%
pruned_vs = ell.vs.select([v for v, b in enumerate(ell.vs) if b['cell_type'] in ['mg1','lg']])

pruned_graph = ell.subgraph(pruned_vs)

degree_all = pruned_graph.degree(mode="in")

visual_style = {}
# visual_style["layout"] = ell.layout("fr")
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = "white"
visual_style["vertex_label"] = degree_all

ig_plot(pruned_graph,edge_width = pruned_graph.es['weight'],
        vertex_color=pruned_graph.vs['color'],
        edge_color = pruned_graph.es['color'], 
        **visual_style)#,vertex_label=labels)

# %% [markdown]
# ## Get all pre-synaptic cells to a specific cellID

# %%
df_edges[df_edges['post']=='393063300'].groupby('pre').sum(numeric_only=True)
# Out:
#            weight  weight_norm
# pre
# 214412684      12          3.0
# 300210608       2          0.5
# 387368998       4          1.0
# 472175645      20          5.0

# %% [markdown]
# ## create crest files for post-syn segments not in cells

# %%
todo_dict= {}
post_segs_without_cell = 0
post_segs_with_cell = 0
for x_pre in ell.vs:
    pre = ecrest(settings_dict,filepath = nodefiles[x_pre['name']],launch_viewer=False)
    
    if pre.cell_data['end_points']['post-synaptic'] != []:

        # for each synapse
        for syn_ in pre.cell_data['end_points']['post-synaptic']:
            post_seg_found=False

            try:
                post_seg = syn_[3]

                # go through each other nodes
                for x_post in ell.vs:

                    post = base_segments[x_post['name']] #ecrest(settings_dict,filepath = nodefiles[x_post['name']],launch_viewer=False)

                    for k,v in post.items():

                        for v_ in list(v): #find keys (can be multiple on the same cell) for matching segment ids

                            if post_seg == v_: 

                            # add edge to the graph between current node and matching node
                                edge_list.append([x_pre['name'],x_post['name'],k])
                                post_seg_found=True
                                if 'mg' in x_pre['cell_type']:
                                    post_segs_with_cell+=1


            except IndexError as msg:
                cellid = x_pre['name']
                print(msg, f'for cell {cellid} synapse at syn_ has no segment id')
            if post_seg_found==False:
                if 'mg' in x_pre['cell_type']:
                    agglo_seg = pre.get_agglo_seg_of_base_seg(post_seg)
                    todo_dict[post_seg] = set(pre.get_base_segs_of_agglo_seg(agglo_seg))
                    post_segs_without_cell+=1

# %%
post_segs_without_cell
# Out:
# 744

# %%
post_segs_with_cell
# Out:
# 569

# %%
topop=[]

todo_inds = list(todo_dict.keys())
for k,k_ in itertools.combinations(todo_inds,2):
    if todo_dict[k]&todo_dict[k_]!=set():
        # then they share segments
        topop.append(k_)
topop = np.unique(topop)

# %%
len(topop)
# Out:
# 170

# %%
for segid in topop:
    todo_dict.pop(segid)

# %% [markdown]
# MAKE SURE THESE CELLS DO NOT OVERLAP WITH ALREADY DONE CELLS

# %%
topop=[]
        
for todo_k,todo_v in todo_dict.items():
    for base_k, base_v in base_segments.items():
        all_base_v = set([a for b in base_v.values() for a in b])
        
        if set(todo_v) & all_base_v != set():
            # then the cell to do actually already exists in the mg_network... that cell is just missing segments!
            topop.append(todo_k)
            print(f'already have this cell as {base_k}; so that cell must be missing segment {todo_k}')
        # if set(todo_segs) & all_segs_base == set():
            
topop = np.unique(topop)
# Out:
# already have this cell as 472051969; so that cell must be missing segment 215495298
# already have this cell as 213605530; so that cell must be missing segment 299452572
# already have this cell as 213605530; so that cell must be missing segment 388917026
# already have this cell as 305332461; so that cell must be missing segment 125582740
# already have this cell as 307591597; so that cell must be missing segment 306463000
# already have this cell as 213669553; so that cell must be missing segment 565183253
# already have this cell as 472051969; so that cell must be missing segment 388483828
# already have this cell as 300210608; so that cell must be missing segment 307080560
# already have this cell as 42800051; so that cell must be missing segment 50585461
# already have this cell as 220213102; so that cell must be missing segment 221374661
# already have this cell as 30117125; so that cell must be missing segment 217984109
# already have this cell as 215526370; so that cell must be missing segment 220121107
# already have this cell as 650610061; so that cell must be missing segment 651785774
# already have this cell as 388406692; so that cell must be missing segment 475410585
# already have this cell as 126649726; so that cell must be missing segment 221295848
# already have this cell as 299404889; so that cell must be missing segment 221295848
# already have this cell as 302143252; so that cell must be missing segment 311288271
# already have this cell as 390542812; so that cell must be missing segment 389393898
# already have this cell as 305035439; so that cell must be missing segment 218018073
# already have this cell as 214503199; so that cell must be missing segment 128630561
# already have this cell as 300210608; so that cell must be missing segment 217892646
# already have this cell as 299497999; so that cell must be missing segment 132032579
# already have this cell as 300316308; so that cell must be missing segment 132032706
# already have this cell as 387368998; so that cell must be missing segment 133130846
# already have this cell as 110418632; so that cell must be missing segment 215525063
# already have this cell as 214412684; so that cell must be missing segment 215525063
# already have this cell as 49453764; so that cell must be missing segment 135313321
# already have this cell as 299404889; so that cell must be missing segment 220215038

# %%
len(topop)
# Out:
# 26

# %%
for segid in topop:
    todo_dict.pop(segid)

# %% [markdown]
# create crest files for each of the unidentified post-synaptic partners

# %%
path_to_settings_json = '/Users/kperks/Documents/ell-connectome/eCREST-local-files/settings_dict.json'
settings_dict = import_settings(path_to_settings_json)

# %%
for segment_id in sorted(list(todo_dict.keys())):

    cell = ecrest(settings_dict,segment_id = segment_id, launch_viewer=False)
    cell.save_cell_graph()
# Out:
# Creating base segment graph for cell 101585973 Cell Reconstruction
# all base locations for 1700 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 101585973. No file saved yet -- save manually.
# Saved cell 101585973 reconstruction locally at 2023-04-09 19.21.15
# Creating base segment graph for cell 126217026 Cell Reconstruction
# all base locations for 1629 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 126217026. No file saved yet -- save manually.
# Saved cell 126217026 reconstruction locally at 2023-04-09 19.21.15
# Creating base segment graph for cell 127312972 Cell Reconstruction
# all base locations for 76 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 127312972. No file saved yet -- save manually.
# Saved cell 127312972 reconstruction locally at 2023-04-09 19.21.15
# Creating base segment graph for cell 128474726 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 128474726. No file saved yet -- save manually.
# Saved cell 128474726 reconstruction locally at 2023-04-09 19.21.15
# Creating base segment graph for cell 128612632 Cell Reconstruction
# all base locations for 79 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 128612632. No file saved yet -- save manually.
# Saved cell 128612632 reconstruction locally at 2023-04-09 19.21.15
# Creating base segment graph for cell 129002351 Cell Reconstruction
# all base locations for 606 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 129002351. No file saved yet -- save manually.
# Saved cell 129002351 reconstruction locally at 2023-04-09 19.21.15
# Creating base segment graph for cell 129017146 Cell Reconstruction
# all base locations for 1224 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 129017146. No file saved yet -- save manually.
# Saved cell 129017146 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 129743652 Cell Reconstruction
# all base locations for 1322 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 129743652. No file saved yet -- save manually.
# Saved cell 129743652 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 129852852 Cell Reconstruction
# all base locations for 263 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 129852852. No file saved yet -- save manually.
# Saved cell 129852852 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130811863 Cell Reconstruction
# all base locations for 731 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130811863. No file saved yet -- save manually.
# Saved cell 130811863 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130920115 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130920115. No file saved yet -- save manually.
# Saved cell 130920115 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130920531 Cell Reconstruction
# all base locations for 19 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130920531. No file saved yet -- save manually.
# Saved cell 130920531 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130933553 Cell Reconstruction
# all base locations for 2019 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130933553. No file saved yet -- save manually.
# Saved cell 130933553 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130950532 Cell Reconstruction
# all base locations for 1511 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130950532. No file saved yet -- save manually.
# Saved cell 130950532 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130965877 Cell Reconstruction
# all base locations for 17 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130965877. No file saved yet -- save manually.
# Saved cell 130965877 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130979425 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130979425. No file saved yet -- save manually.
# Saved cell 130979425 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 130980088 Cell Reconstruction
# all base locations for 11 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 130980088. No file saved yet -- save manually.
# Saved cell 130980088 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 131104112 Cell Reconstruction
# all base locations for 448 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 131104112. No file saved yet -- save manually.
# Saved cell 131104112 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 131183833 Cell Reconstruction
# all base locations for 26 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 131183833. No file saved yet -- save manually.
# Saved cell 131183833 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 131987117 Cell Reconstruction
# all base locations for 1793 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 131987117. No file saved yet -- save manually.
# Saved cell 131987117 reconstruction locally at 2023-04-09 19.21.16
# Creating base segment graph for cell 132003595 Cell Reconstruction
# all base locations for 44 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132003595. No file saved yet -- save manually.
# Saved cell 132003595 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132032774 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132032774. No file saved yet -- save manually.
# Saved cell 132032774 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132032813 Cell Reconstruction
# all base locations for 32 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132032813. No file saved yet -- save manually.
# Saved cell 132032813 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132034135 Cell Reconstruction
# all base locations for 6 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132034135. No file saved yet -- save manually.
# Saved cell 132034135 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132063155 Cell Reconstruction
# all base locations for 13 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132063155. No file saved yet -- save manually.
# Saved cell 132063155 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132063637 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132063637. No file saved yet -- save manually.
# Saved cell 132063637 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132096758 Cell Reconstruction
# all base locations for 37 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132096758. No file saved yet -- save manually.
# Saved cell 132096758 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132205966 Cell Reconstruction
# all base locations for 3857 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132205966. No file saved yet -- save manually.
# Saved cell 132205966 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132220454 Cell Reconstruction
# all base locations for 11 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132220454. No file saved yet -- save manually.
# Saved cell 132220454 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132284460 Cell Reconstruction
# all base locations for 85 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132284460. No file saved yet -- save manually.
# Saved cell 132284460 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132296056 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132296056. No file saved yet -- save manually.
# Saved cell 132296056 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132356952 Cell Reconstruction
# all base locations for 9 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132356952. No file saved yet -- save manually.
# Saved cell 132356952 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132450165 Cell Reconstruction
# all base locations for 23 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132450165. No file saved yet -- save manually.
# Saved cell 132450165 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132451068 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132451068. No file saved yet -- save manually.
# Saved cell 132451068 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132452390 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132452390. No file saved yet -- save manually.
# Saved cell 132452390 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132452730 Cell Reconstruction
# all base locations for 1452 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132452730. No file saved yet -- save manually.
# Saved cell 132452730 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132465434 Cell Reconstruction
# all base locations for 4 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132465434. No file saved yet -- save manually.
# Saved cell 132465434 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 132669410 Cell Reconstruction
# all base locations for 3123 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 132669410. No file saved yet -- save manually.
# Saved cell 132669410 reconstruction locally at 2023-04-09 19.21.17
# Creating base segment graph for cell 133130906 Cell Reconstruction
# all base locations for 3674 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133130906. No file saved yet -- save manually.
# Saved cell 133130906 reconstruction locally at 2023-04-09 19.21.18
# Creating base segment graph for cell 133162957 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133162957. No file saved yet -- save manually.
# Saved cell 133162957 reconstruction locally at 2023-04-09 19.21.18
# Creating base segment graph for cell 133178221 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133178221. No file saved yet -- save manually.
# Saved cell 133178221 reconstruction locally at 2023-04-09 19.21.18
# Creating base segment graph for cell 133225259 Cell Reconstruction
# all base locations for 156 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133225259. No file saved yet -- save manually.
# Saved cell 133225259 reconstruction locally at 2023-04-09 19.21.18
# Creating base segment graph for cell 133362832 Cell Reconstruction
# all base locations for 6712 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133362832. No file saved yet -- save manually.
# Saved cell 133362832 reconstruction locally at 2023-04-09 19.21.18
# Creating base segment graph for cell 133440386 Cell Reconstruction
# all base locations for 1403 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133440386. No file saved yet -- save manually.
# Saved cell 133440386 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 133503727 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133503727. No file saved yet -- save manually.
# Saved cell 133503727 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 133563832 Cell Reconstruction
# all base locations for 9 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 133563832. No file saved yet -- save manually.
# Saved cell 133563832 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 134324258 Cell Reconstruction
# all base locations for 1686 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 134324258. No file saved yet -- save manually.
# Saved cell 134324258 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 134353352 Cell Reconstruction
# all base locations for 25 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 134353352. No file saved yet -- save manually.
# Saved cell 134353352 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 134511745 Cell Reconstruction
# all base locations for 6 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 134511745. No file saved yet -- save manually.
# Saved cell 134511745 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 134634255 Cell Reconstruction
# all base locations for 587 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 134634255. No file saved yet -- save manually.
# Saved cell 134634255 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 134724351 Cell Reconstruction
# all base locations for 41 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 134724351. No file saved yet -- save manually.
# Saved cell 134724351 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135312654 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135312654. No file saved yet -- save manually.
# Saved cell 135312654 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135436300 Cell Reconstruction
# all base locations for 1639 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135436300. No file saved yet -- save manually.
# Saved cell 135436300 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135453795 Cell Reconstruction
# all base locations for 22 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135453795. No file saved yet -- save manually.
# Saved cell 135453795 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135559868 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135559868. No file saved yet -- save manually.
# Saved cell 135559868 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135559932 Cell Reconstruction
# all base locations for 12 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135559932. No file saved yet -- save manually.
# Saved cell 135559932 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135562406 Cell Reconstruction
# all base locations for 999 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135562406. No file saved yet -- save manually.
# Saved cell 135562406 reconstruction locally at 2023-04-09 19.21.19
# Creating base segment graph for cell 135578682 Cell Reconstruction
# all base locations for 5908 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135578682. No file saved yet -- save manually.
# Saved cell 135578682 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 135609757 Cell Reconstruction
# all base locations for 48 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135609757. No file saved yet -- save manually.
# Saved cell 135609757 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 135655606 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135655606. No file saved yet -- save manually.
# Saved cell 135655606 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 135656252 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 135656252. No file saved yet -- save manually.
# Saved cell 135656252 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 136596666 Cell Reconstruction
# all base locations for 46 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 136596666. No file saved yet -- save manually.
# Saved cell 136596666 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 137171038 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 137171038. No file saved yet -- save manually.
# Saved cell 137171038 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 137204021 Cell Reconstruction
# all base locations for 2552 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 137204021. No file saved yet -- save manually.
# Saved cell 137204021 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 137204415 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 137204415. No file saved yet -- save manually.
# Saved cell 137204415 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 138391672 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 138391672. No file saved yet -- save manually.
# Saved cell 138391672 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 138391701 Cell Reconstruction
# all base locations for 3 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 138391701. No file saved yet -- save manually.
# Saved cell 138391701 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 138392148 Cell Reconstruction
# all base locations for 9 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 138392148. No file saved yet -- save manually.
# Saved cell 138392148 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 139551907 Cell Reconstruction
# all base locations for 4 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 139551907. No file saved yet -- save manually.
# Saved cell 139551907 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 139551954 Cell Reconstruction
# all base locations for 16 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 139551954. No file saved yet -- save manually.
# Saved cell 139551954 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 139553487 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 139553487. No file saved yet -- save manually.
# Saved cell 139553487 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 189284850 Cell Reconstruction
# all base locations for 291 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 189284850. No file saved yet -- save manually.
# Saved cell 189284850 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 198648129 Cell Reconstruction
# all base locations for 128 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 198648129. No file saved yet -- save manually.
# Saved cell 198648129 reconstruction locally at 2023-04-09 19.21.20
# Creating base segment graph for cell 204140986 Cell Reconstruction
# all base locations for 5030 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 204140986. No file saved yet -- save manually.
# Saved cell 204140986 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 207637166 Cell Reconstruction
# all base locations for 382 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 207637166. No file saved yet -- save manually.
# Saved cell 207637166 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 207761438 Cell Reconstruction
# all base locations for 594 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 207761438. No file saved yet -- save manually.
# Saved cell 207761438 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 213452074 Cell Reconstruction
# all base locations for 719 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 213452074. No file saved yet -- save manually.
# Saved cell 213452074 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 213668352 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 213668352. No file saved yet -- save manually.
# Saved cell 213668352 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 214366905 Cell Reconstruction
# all base locations for 99 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 214366905. No file saved yet -- save manually.
# Saved cell 214366905 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 214382460 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 214382460. No file saved yet -- save manually.
# Saved cell 214382460 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 214397605 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 214397605. No file saved yet -- save manually.
# Saved cell 214397605 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 214829957 Cell Reconstruction
# all base locations for 13 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 214829957. No file saved yet -- save manually.
# Saved cell 214829957 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 214847324 Cell Reconstruction
# all base locations for 313 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 214847324. No file saved yet -- save manually.
# Saved cell 214847324 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 215030183 Cell Reconstruction
# all base locations for 4060 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 215030183. No file saved yet -- save manually.
# Saved cell 215030183 reconstruction locally at 2023-04-09 19.21.21
# Creating base segment graph for cell 215494931 Cell Reconstruction
# all base locations for 944 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 215494931. No file saved yet -- save manually.
# Saved cell 215494931 reconstruction locally at 2023-04-09 19.21.22
# Creating base segment graph for cell 215509888 Cell Reconstruction
# all base locations for 239 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 215509888. No file saved yet -- save manually.
# ...
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 564859739. No file saved yet -- save manually.
# Saved cell 564859739 reconstruction locally at 2023-04-09 19.21.41
# Creating base segment graph for cell 564997266 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 564997266. No file saved yet -- save manually.
# Saved cell 564997266 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 565695733 Cell Reconstruction
# all base locations for 5 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 565695733. No file saved yet -- save manually.
# Saved cell 565695733 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 565696071 Cell Reconstruction
# all base locations for 869 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 565696071. No file saved yet -- save manually.
# Saved cell 565696071 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 566314594 Cell Reconstruction
# all base locations for 40 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 566314594. No file saved yet -- save manually.
# Saved cell 566314594 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 566408743 Cell Reconstruction
# all base locations for 36 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 566408743. No file saved yet -- save manually.
# Saved cell 566408743 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 567627928 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 567627928. No file saved yet -- save manually.
# Saved cell 567627928 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 567642989 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 567642989. No file saved yet -- save manually.
# Saved cell 567642989 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 568774583 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 568774583. No file saved yet -- save manually.
# Saved cell 568774583 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 568865204 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 568865204. No file saved yet -- save manually.
# Saved cell 568865204 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 643880266 Cell Reconstruction
# all base locations for 3234 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 643880266. No file saved yet -- save manually.
# Saved cell 643880266 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 644173603 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 644173603. No file saved yet -- save manually.
# Saved cell 644173603 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 644173607 Cell Reconstruction
# all base locations for 4625 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 644173607. No file saved yet -- save manually.
# Saved cell 644173607 reconstruction locally at 2023-04-09 19.21.42
# Creating base segment graph for cell 644824967 Cell Reconstruction
# all base locations for 4073 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 644824967. No file saved yet -- save manually.
# Saved cell 644824967 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 645334982 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 645334982. No file saved yet -- save manually.
# Saved cell 645334982 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 647220636 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 647220636. No file saved yet -- save manually.
# Saved cell 647220636 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 647223184 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 647223184. No file saved yet -- save manually.
# Saved cell 647223184 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 647236415 Cell Reconstruction
# all base locations for 7 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 647236415. No file saved yet -- save manually.
# Saved cell 647236415 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 647238132 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 647238132. No file saved yet -- save manually.
# Saved cell 647238132 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 647238364 Cell Reconstruction
# all base locations for 2 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 647238364. No file saved yet -- save manually.
# Saved cell 647238364 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 647640030 Cell Reconstruction
# all base locations for 1031 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 647640030. No file saved yet -- save manually.
# Saved cell 647640030 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 648444922 Cell Reconstruction
# all base locations for 3 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 648444922. No file saved yet -- save manually.
# Saved cell 648444922 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 648754302 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 648754302. No file saved yet -- save manually.
# Saved cell 648754302 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 648754333 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 648754333. No file saved yet -- save manually.
# Saved cell 648754333 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 650733978 Cell Reconstruction
# all base locations for 4 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 650733978. No file saved yet -- save manually.
# Saved cell 650733978 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 651106006 Cell Reconstruction
# all base locations for 297 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 651106006. No file saved yet -- save manually.
# Saved cell 651106006 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 651138494 Cell Reconstruction
# all base locations for 1 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 651138494. No file saved yet -- save manually.
# Saved cell 651138494 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 652282217 Cell Reconstruction
# all base locations for 839 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 652282217. No file saved yet -- save manually.
# Saved cell 652282217 reconstruction locally at 2023-04-09 19.21.43
# Creating base segment graph for cell 653242015 Cell Reconstruction
# all base locations for 20 obtained from SQL database
# graph created among all_base_segs
# 1 clusters of connected components. Connecting these clusters with nearest base segments.
# weak clusters connected
# segments without a location connected
# 1 clusters in graph (note should/would be only 1 if loaded base ID from agglomo fresh)
# Created a CREST instance for NEW Reconstruction of 653242015. No file saved yet -- save manually.
# Saved cell 653242015 reconstruction locally at 2023-04-09 19.21.43

# %% [markdown]
# check out the cells...
# after completing one, make sure to check that it is not one of the currenlty "undone cells"

# %% [markdown]
# load one of the cells

# %%
filename = 'cell_graph_128473437__2023-04-07 19.33.39.json'
todo_cell = ecrest(settings_dict,filepath = Path(settings_dict['save_dir'])/filename,launch_viewer=True)
# Out:
# updating viewer status message: Current Base Segment Counts: unknown: 966, axon: 161, basal dendrite: 105, apical dendrite: 733, dendrite: 0, multiple: 9

# %%
todo_cell.define_ctype('lf','manual')
todo_cell.get_ctype('manual')
# Out:
# 'mg2'

# %%
todo_cell.save_cell_graph()
# Out:
# Saved cell 128473437 reconstruction locally at 2023-04-08 06.08.54

# %%
todo_cell.cell_data['metadata']
# Out:
# {'main_seg': {'agglo': {'brainmaps://10393113184:ell:roi450um_seg32fb16fb_220930:v230111c_16_strict_only_spl': '45057587'},
#   'base': '472114046'},
#  'data_sources': {'em': 'brainmaps://10393113184:ell:roi450um_xyz',
#   'base': 'brainmaps://10393113184:ell:roi450um_seg32fb16fb_220930',
#   'agglo': 'brainmaps://10393113184:ell:roi450um_seg32fb16fb_220930:v230111c_16_strict_only_spl'},
#  'timing': [],
#  'completion': [],
#  'cell-type': {'manual': [], 'auto': []},
#  'old-anchor': ['302559454']}
# 379 other base segments in the agglo segment; max number can add is 1000
# Added 379 base segments from agglomerated segment 51850046, linked base segments 391933143 and 136613253, 7901nm apart,
# 2 base segments removed from 2 connected components
# 1 base segments removed from 1 connected components
# 1 base segments removed from 1 connected components
# 1 base segments removed from 1 connected components
# 1 base segments removed from 1 connected components
# 262 base segments removed from 2 connected components
# 1 other base segments in the agglo segment; max number can add is 1000
# Added 1 base segments from agglomerated segment 646137862, linked base segments 646137527 and 646137862, 2285nm apart,
# 1 other base segments in the agglo segment; max number can add is 1000
# Added 1 base segments from agglomerated segment 646138530, linked base segments 646137862 and 646138530, 3245nm apart,
# 1 other base segments in the agglo segment; max number can add is 1000
# Added 1 base segments from agglomerated segment 646139240, linked base segments 646139162 and 646139240, 228nm apart,
# 1 other base segments in the agglo segment; max number can add is 1000
# Added 1 base segments from agglomerated segment 648337689, linked base segments 648337125 and 648337689, 1517nm apart,
# 1 other base segments in the agglo segment; max number can add is 1000
# Added 1 base segments from agglomerated segment 391933921, linked base segments 391933551 and 391933921, 785nm apart,
# 323 base segments removed from 189 connected components

# %% [markdown]
# ### Check to make sure this cell is not already on the high priority sheet as "undone"

# %%
all_segs = [a for b in todo_cell.cell_data['base_segments'].values() for a in b]

# %%
# if it is actually a new cell, this should return an empty set
set(all_segs)&set(undone)
# Out:
# set()

# %% [markdown]
# ## GET most recent files (by filename date) in folder

# %%
dirname = 'C:/Users/mpetkova/Dropbox/U19_zebrafish/EMfullres/LateralLineCurlDetector/CREST/right_afferents/'
# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'C:/Users/EngertLab/Dropbox/CREST/mariela_fish_credentials.json'

names = os.listdir(dirname);
cellid_filename=list();
for ind in range(len(names)):
    content = names[ind].split('_')
    if ('cell' in content):
        cellid_filename.append(names[ind])
d={}
for name in cellid_filename:
    ID,content_type,date=name.split('_')[2], name.split('_')[0], name.split('_')[-1]
    date=date[:-5]
    #create entry in dict which holds ID, file type (ex: cell_graph) and file path
    if ID not in d:
        d[ID]=[date, name]
        #if there are multiple files with the same ID, keep the info for the newest one
    else:
        if date>d[ID][0]:
            d[ID][0]=date
            d[ID][1]=name
            
############################################################################################################################ 
# Collect all the base segments for each ID
import json

base_segs = {}

for key in d.keys():
    f = open(dirname+d[key][1])
    data = json.load(f)
    base_segs[key]=sum(data['base_segments'].values(),[])
    f.close()

############################################################################################################################

# %% [markdown]
# ## Fix cell_data dictionary keys

# %%
filepath = Path("/Users/kperks/Documents/gdrive/.shortcut-targets-by-id/16q1BuOMfD2ta0Cwq8CjMlRe4rDvbuWC5/ELL_connectome/CREST_reconstructions/mg-network/")
filepath = filepath / "cell_graph_305332461__2023-04-01 21.04.03.json"

# %%
cell = ecrest(settings_dict,filepath = filepath,launch_viewer=False)

# %%
old_points = cell.cell_data['end_points']
old_points
# Out:
# {'exit volume': [],
#  'natural': [],
#  'bad alignment': [],
#  'uncorrected split': [],
#  'artefact': [],
#  'natural end': [],
#  'uncertain': [],
#  'pre-synaptic': [],
#  'post-synaptic': []}

# %%
end_points = {}
for p in cell.point_types:
    # if p not in cell.cell_data['end_points']:
    end_points[p] = []
        
cell.cell_data['end_points'] = end_points

# %%
cell.cell_data['end_points']['natural end'] = old_points['natural']

# %%
# cell.cell_data['end_points'].pop('natural')
cell.cell_data['end_points'].keys()
# Out:
# dict_keys(['exit volume', 'natural end', 'uncertain', 'pre-synaptic', 'post-synaptic'])

# %%
cell.save_cell_graph(directory_path = filepath.parent, file_name=filepath.name, save_to_cloud=False); #rewrites the original, not with a new time stamp
# Out:
# Saved cell 305332461 reconstruction locally at 2023-04-05 11.20.24

# %% [markdown]
# ## Figure out what is wrong with a crest file

# %%
filepath = Path("/Users/kperks/Documents/gdrive/.shortcut-targets-by-id/16q1BuOMfD2ta0Cwq8CjMlRe4rDvbuWC5/ELL_connectome/CREST_reconstructions/mg-network/")
filepath = filepath / "cell_graph_213605530__2023-03-29 22.49.21.json"
cell = ecrest(settings_dict,filepath = filepath,launch_viewer=False)

# %%
cell.cell_data['end_points']['post-synaptic']
# Out:
# []

# %% [markdown]
# ## Fix pre-synaptic to be post-synaptic annotation list in converted crest jsons

# %%
json_fix = Path("/Users/kperks/Documents/gdrive/.shortcut-targets-by-id/16q1BuOMfD2ta0Cwq8CjMlRe4rDvbuWC5/ELL_connectome/Complete/synapses/to-crest/conversion_specs_synapse_fix.json")

with open(json_fix,'r') as f:
    cells_to_fix = f.read()
    cells_to_fix = json.loads(cells_to_fix)

# %%
cells_to_fix = cells_to_fix['cell_info']

# %%
for k,v in cells_to_fix.items():
    try:
        filepath = nodefiles[k]
        cell = ecrest(settings_dict,filepath = filepath,launch_viewer=False)
        cell.cell_data['end_points']['post-synaptic'] = deepcopy(cell.cell_data['end_points']['pre-synaptic'])

        cell.cell_data['end_points']['pre-synaptic'] = []
        # cell.save_cell_graph(directory_path = filepath.parent / 'original', file_name=filepath.name, save_to_cloud=False); #rewrites the original, not with a new time stamp
    except KeyError as msg:
        print(msg)
        continue
# Out:
# Saved cell 214412684 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 214550811 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 215572949 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 216129202 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 220275752 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 297178666 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 299497999 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 299589324 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 300210608 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 300316308 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 300380579 reconstruction locally at 2023-04-05 12.11.10
# "305035439'"
# Saved cell 31102601 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 387368998 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 392213717 reconstruction locally at 2023-04-05 12.11.10
# Saved cell 42802314 reconstruction locally at 2023-04-05 12.11.11
# '472161980'
# Saved cell 472175645 reconstruction locally at 2023-04-05 12.11.11
# Saved cell 472409584 reconstruction locally at 2023-04-05 12.11.11
# Saved cell 480066826 reconstruction locally at 2023-04-05 12.11.11
# Saved cell 49530373 reconstruction locally at 2023-04-05 12.11.11

# %%
cell.cell_data['end_points']
# Out:
# {'exit volume': [],
#  'natural end': [[142609.46875, 275542.6875, 45.0],
#   [142776.15625, 278173.6875, 2775.0],
#   [53208.87890625, 271123.09375, 13365.0],
#   [70813.0859375, 267435.34375, 10044.652404785156],
#   [51008.359375, 284277.96875, 56675.0830078125],
#   [68367.4921875, 273829.5625, 31418.91357421875],
#   [64639.48046875, 274508.65625, 35085.003662109375],
#   [62399.1796875, 303022.0625, 106049.47265625],
#   [54059.69921875, 292912.375, 77115.0],
#   [115337.7109375, 289251.84375, 74204.99267578125],
#   [140118.015625, 284278.375, 106005.0],
#   [142204.484375, 284977.09375, 106005.0],
#   [111865.0390625, 291143.6875, 67154.99267578125],
#   [110964.0390625, 289608.1875, 66825.0],
#   [109141.9609375, 289524.5625, 66975.0],
#   [106861.765625, 289384.875, 68985.0],
#   [222726.3125, 265308.8125, 60494.996337890625],
#   [185022.09375, 273914.90625, 45135.0],
#   [184830.203125, 272752.84375, 52605.0],
#   [169899.09375, 265474.03125, 13754.999084472656],
#   [135296.546875, 277537.78125, 40934.996337890625],
#   [122864.8046875, 270745.4375, 31184.996337890625],
#   [137723.015625, 312193.65625, 106035.0],
#   [137060.875, 313303.625, 102337.37548828125],
#   [140551.875, 311073.71875, 78974.99267578125],
#   [200516.203125, 311475.6875, 106035.0],
#   [192419.9375, 310598.125, 96764.99267578125],
#   [183279.203125, 310559.15625, 93345.0],
#   [130835.0390625, 192378.203125, 106035.0],
#   [81289.7109375, 179026.671875, 106035.0],
#   [90222.59375, 208912.078125, 106035.0],
#   [192105.296875, 49391.17578125, 9614.999084472656],
#   [212747.71875, 49180.796875, 61094.99267578125],
#   [124347.953125, 52019.859375, 106035.0],
#   [155152.578125, 76213.7265625, 45.0],
#   [133582.078125, 128614.546875, 106035.0],
#   [134242.03125, 98370.8203125, 106035.0],
#   [113433.1484375, 99209.953125, 106035.0],
#   [182430.203125, 49238.4609375, 34124.996337890625],
#   [93554.6640625, 73034.8515625, 104906.46240234375],
#   [88471.875, 119794.3125, 38834.996337890625],
#   [55033.328125, 84431.0703125, 40455.003662109375],
#   [67395.7734375, 70934.171875, 65925.00732421875],
#   [124569.890625, 55806.61328125, 69015.00732421875],
#   [74379.4140625, 84828.9765625, 45.0],
#   [83033.75, 86694.6015625, 25305.0],
#   [91617.828125, 104709.140625, 45.0],
#   [141076.125, 60318.34375, 106035.0],
#   [215211.328125, 308878.625, 53954.996337890625],
#   [214443.046875, 307279.96875, 54344.996337890625],
#   [215030.859375, 307986.46875, 52575.0],
#   [214712.859375, 302142.6875, 62385.00732421875],
#   [214104.203125, 304233.90625, 60854.996337890625],
#   [189899.59375, 311289.40625, 48975.0],
#   [183343.78125, 311370.34375, 44205.0],
#   [181160.03125, 310586.78125, 43245.0],
#   [170115.796875, 310241.25, 37575.0],
#   [168698.96875, 311308.71875, 37034.996337890625],
#   [154350.265625, 313316.1875, 37544.996337890625],
#   [152391.453125, 310610.8125, 45.0],
#   [153568.765625, 310708.3125, 2715.000228881836],
#   [137728.703125, 310831.78125, 33255.003662109375],
#   [141694.96875, 310141.375, 50775.00732421875],
#   [162656.5, 323412.5625, 5775.000457763672],
#   [161882.171875, 324019.03125, 6008.211822509766],
#   [174081.75, 311736.1875, 4869.499969482422],
#   [175620.734375, 311505.1875, 11204.999084472656],
#   [176342.515625, 310904.40625, 8715.0],
#   [173013.703125, 311588.125, 8327.289733886719],
#   [171701.1875, 311510.78125, 8654.999084472656],
#   [169689.0, 310699.90625, 6794.999084472656],
#   [169953.203125, 311584.03125, 7065.0],
#   [150787.890625, 329012.25, 32775.0],
#   [150811.59375, 328484.53125, 34214.996337890625],
#   [151155.734375, 326433.0, 37514.996337890625],
#   [144179.609375, 316226.78125, 41535.0],
#   [126132.1015625, 317534.4375, 27014.998168945312],
#   [125275.65625, 317271.84375, 26084.998168945312],
#   [124675.6796875, 318120.6875, 25844.998168945312],
#   [136838.90625, 311748.375, 4455.0],
#   [132672.9375, 310965.5, 3705.000228881836],
#   [134711.140625, 314111.90625, 42495.003662109375],
#   [137472.484375, 309393.09375, 46785.0],
#   [78388.6796875, 315089.40625, 106035.0],
#   [56271.62109375, 318292.40625, 36254.996337890625],
#   [36406.5625, 318730.25, 59355.003662109375],
#   [36906.96875, 318733.28125, 58664.996337890625],
#   [30937.228515625, 320357.75, 62595.0],
#   [34140.55859375, 321677.53125, 61725.0],
#   [38609.1953125, 317320.8125, 55395.003662109375],
#   [39111.91796875, 316482.65625, 51765.003662109375],
#   [43218.67578125, 316450.96875, 48795.0],
#   [62954.66796875, 314006.625, 53445.00732421875],
#   [47927.6875, 317762.5, 69915.0],
#   [32473.51953125, 324043.25, 84885.0],
#   [73807.90625, 312036.875, 17924.998168945312],
#   [64130.23828125, 311797.0625, 13305.0],
#   [34540.015625, 317452.46875, 6524.999542236328],
#   [98563.9453125, 310230.6875, 21315.0],
#   [98442.4296875, 308578.15625, 25005.0],
#   [101650.9140625, 310098.0, 26985.001831054688],
#   [106998.640625, 309657.78125, 33675.003662109375],
#   [106726.640625, 308553.78125, 34095.003662109375],
#   [104712.7265625, 310591.125, 32595.0],
#   [105705.3515625, 309894.53125, 32745.003662109375]],
#  'uncertain': [],
#  'pre-synaptic': [],
#  'post-synaptic': [[222438.765625,
#    266163.84375,
#    60164.99267578125,
#    '385188039'],
#   [222150.640625, 264922.28125, 60225.00732421875, '207761438'],
#   [222024.890625, 267046.09375, 57765.0, '387491152'],
#   [221821.09375, 266376.46875, 58124.996337890625, '386346210'],
#   [221122.375, 267628.375, 57824.996337890625, '299344334'],
#   [220142.234375, 269705.28125, 57824.996337890625, '385188039'],
#   [218304.78125, 272044.125, 56085.003662109375, '301603337'],
#   [219175.921875, 273562.75, 55695.003662109375, '301619421'],
#   [184640.65625, 274442.0625, 45675.003662109375, '215666697'],
#   [185299.90625, 274542.125, 45465.003662109375, '302684381'],
#   [185364.640625, 274118.34375, 46725.0, '301538610'],
#   [186329.46875, 274646.8125, 51855.0, '302667883'],
#   [170126.8125, 265266.3125, 13875.0, '41564382'],
#   [173270.828125, 266121.875, 17505.001831054688, '128612633'],
#   [174976.484375, 267636.78125, 20595.001831054688, '129758863'],
#   [176047.40625, 268245.4375, 21195.001831054688, '128612633'],
#   [174134.953125, 268264.1875, 20925.001831054688, '128612632'],
#   [175716.90625, 268953.3125, 26715.001831054688, '129744690'],
#   [175769.859375, 268088.0625, 27945.0, '215647260'],
#   [175030.609375, 268507.8125, 32265.003662109375, '215633294'],
#   [134582.828125, 277103.125, 40845.0, '130812329'],
#   [132883.890625, 276403.46875, 41715.0, '302559454'],
#   [129092.6171875, 275796.625, 42405.0, '302559664'],
#   [127891.5546875, 276132.71875, 41895.0, '302559111'],
#   [123086.421875, 269439.5625, 33945.003662109375, '115945511'],
#   [122927.5234375, 268533.125, 33945.003662109375, '215525266'],
#   [123698.5546875, 269569.0625, 34605.0, '130812329'],
#   [123180.609375, 268391.84375, 35025.0, '215525737'],
#   [120918.5625, 267548.90625, 37755.003662109375, '130812329'],
#   [119834.46875, 267233.09375, 40095.003662109375, '215511594'],
#   [118698.4375, 266762.125, 40035.003662109375, '214366905'],
#   [118990.890625, 268249.0625, 43065.0, '111345587'],
#   [118393.8359375, 269207.9375, 44091.01318359375, '301384141'],
#   [118357.6953125, 267847.09375, 44595.003662109375, '300238999'],
#   [117708.5625, 270587.0625, 45555.0, '300238999'],
#   [117996.9765625, 270769.53125, 45045.003662109375, '301384808'],
#   [70899.265625, 267728.40625, 10065.0, '40229907'],
#   [64805.5078125, 267682.625, 9255.000915527344, '43637142'],
#   [61313.9765625, 268318.71875, 9435.000915527344, '43637214'],
#   [60731.25, 268189.21875, 9225.0, '43620822'],
#   [56518.765625, 271486.5, 11625.0, '43622129'],
#   [54586.29296875, 271913.15625, 11655.0, '42476420'],
#   [54150.72265625, 271147.96875, 11355.000915527344, '41348014'],
#   [55226.171875, 270553.3125, 10605.000915527344, '41348014'],
#   [56132.625, 270871.15625, 10275.000915527344, '43621743'],
#   [54094.2578125, 270927.34375, 13095.001831054688, '43622281'],
#   [52987.67578125, 270791.96875, 13245.000915527344, '43621993'],
#   [76980.3359375, 281484.90625, 12794.999084472656, '45958431'],
#   [78685.75, 282098.96875, 14385.0, '131830315'],
#   [68648.90625, 274140.65625, 31994.996337890625, '119179690'],
#   [67494.0703125, 273422.53125, 32984.996337890625, '119179690'],
#   [64262.49609375, 274684.125, 34875.0, '123804398'],
#   [65362.77734375, 275698.90625, 36254.996337890625, '119179690'],
#   [64110.91015625, 276387.9375, 36494.996337890625, '216547178'],
#   [65411.3125, 277300.15625, 38204.996337890625, '119179690'],
#   [52007.59765625, 284414.5625, 56714.996337890625, '301247367'],
#   [51299.17578125, 283929.375, 56684.996337890625, '389393898'],
#   [51687.35546875, 285045.40625, 55935.0, '389409910'],
#   [56595.0703125, 279360.3125, 55364.996337890625, '388264713'],
#   [55925.4609375, 279535.0, 55184.99267578125, '211953945'],
#   [56195.5859375, 279067.125, 53445.00732421875, '388264300'],
#   [54498.90625, 293680.34375, 75884.99267578125, '476432190'],
#   [53945.75, 292399.34375, 76814.99267578125, '476432449'],
#   [61975.5078125, 291960.90625, 69494.99267578125, '476445559'],
#   [63790.24609375, 292504.375, 68384.99267578125, '390572721'],
#   [142478.109375, 284582.59375, 105615.0, '647238132'],
#   [142206.390625, 286096.46875, 105644.99267578125, '393031999'],
#   [114504.7734375, 289958.1875, 75224.99267578125, '388422459'],
#   [114068.0703125, 288978.03125, 74504.99267578125, '476570050'],
#   [112073.4609375, 291612.40625, 67515.0, '476553358'],
#   [111209.7734375, 289535.59375, 67454.99267578125, '305889380'],
#   [108346.90625, 288759.15625, 67454.99267578125, '305889380'],
#   [105891.6640625, 288574.75, 68625.0, '305889380'],
#   [103718.8125, 289757.8125, 69824.99267578125, '305889380']]}

# %% [markdown]
# ## Anatomical Clustering
